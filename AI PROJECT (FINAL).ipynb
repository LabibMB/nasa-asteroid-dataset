# %% [markdown]
# # AI Group Project

# %% [markdown]
# ### NASA: Asteroids Classification Dataset Analysis

# %% [markdown]
# Dataset Link:
# https://www.kaggle.com/datasets/shrutimehta/nasa-asteroids-classification?resource=download

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading dataset
df = pd.read_csv('nasa.csv')

# %%
#different columns in the dataset
df.columns
# Out:
# Index(['Neo Reference ID', 'Name', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Est Dia in M(min)', 'Est Dia in M(max)',
#        'Est Dia in Miles(min)', 'Est Dia in Miles(max)',
#        'Est Dia in Feet(min)', 'Est Dia in Feet(max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity km per sec',
#        'Relative Velocity km per hr', 'Miles per hour',
#        'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
#        'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Equinox', 'Hazardous'],
#       dtype='object')

# %%
#first 5 rows of the datset
df.head()
# Out:
#    Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0           3703080  3703080                21.6            0.127220
# 1           3723955  3723955                21.3            0.146068
# 2           2446862  2446862                20.3            0.231502
# 3           3092506  3092506                27.4            0.008801
# 4           3514799  3514799                21.6            0.127220
#
#    Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 0            0.284472         127.219879         284.472297
# 1            0.326618         146.067964         326.617897
# 2            0.517654         231.502122         517.654482
# 3            0.019681           8.801465          19.680675
# 4            0.284472         127.219879         284.472297
#
#    Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# 0               0.079051               0.176763            417.388066  ...
# ...

# %%
#5 last rows of the datset
df.tail()
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# 4682            0.098637          44.111820          98.637028
# 4683            0.013616           6.089126          13.615700
# 4684            0.171412          76.657557         171.411509
# 4685            0.259442         116.025908         259.441818
# 4686            0.895860         400.640618         895.859655
#
#       Est Dia in Miles(min)  Est Dia in Miles(max)  Est Dia in Feet(min)  ...  \
# ...

# %%
#check for missing data
df.isna().sum()
# Out:
# Neo Reference ID                0
# Name                            0
# Absolute Magnitude              0
# Est Dia in KM(min)              0
# Est Dia in KM(max)              0
# Est Dia in M(min)               0
# Est Dia in M(max)               0
# Est Dia in Miles(min)           0
# Est Dia in Miles(max)           0
# Est Dia in Feet(min)            0
# Est Dia in Feet(max)            0
# Close Approach Date             0
# Epoch Date Close Approach       0
# Relative Velocity km per sec    0
# Relative Velocity km per hr     0
# Miles per hour                  0
# Miss Dist.(Astronomical)        0
# Miss Dist.(lunar)               0
# Miss Dist.(kilometers)          0
# Miss Dist.(miles)               0
# Orbiting Body                   0
# Orbit ID                        0
# Orbit Determination Date        0
# Orbit Uncertainity              0
# Minimum Orbit Intersection      0
# Jupiter Tisserand Invariant     0
# Epoch Osculation                0
# ...

# %%
#checking data types present in the dataser
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4687 entries, 0 to 4686
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Neo Reference ID              4687 non-null   int64
#  1   Name                          4687 non-null   int64
#  2   Absolute Magnitude            4687 non-null   float64
#  3   Est Dia in KM(min)            4687 non-null   float64
#  4   Est Dia in KM(max)            4687 non-null   float64
#  5   Est Dia in M(min)             4687 non-null   float64
#  6   Est Dia in M(max)             4687 non-null   float64
#  7   Est Dia in Miles(min)         4687 non-null   float64
#  8   Est Dia in Miles(max)         4687 non-null   float64
#  9   Est Dia in Feet(min)          4687 non-null   float64
#  10  Est Dia in Feet(max)          4687 non-null   float64
#  11  Close Approach Date           4687 non-null   object
# ...

# %%
df[df['Hazardous'] ==True].count()
# Out:
# Neo Reference ID                755
# Name                            755
# Absolute Magnitude              755
# Est Dia in KM(min)              755
# Est Dia in KM(max)              755
# Est Dia in M(min)               755
# Est Dia in M(max)               755
# Est Dia in Miles(min)           755
# Est Dia in Miles(max)           755
# Est Dia in Feet(min)            755
# Est Dia in Feet(max)            755
# Close Approach Date             755
# Epoch Date Close Approach       755
# Relative Velocity km per sec    755
# Relative Velocity km per hr     755
# Miles per hour                  755
# Miss Dist.(Astronomical)        755
# Miss Dist.(lunar)               755
# Miss Dist.(kilometers)          755
# Miss Dist.(miles)               755
# Orbiting Body                   755
# Orbit ID                        755
# Orbit Determination Date        755
# Orbit Uncertainity              755
# Minimum Orbit Intersection      755
# Jupiter Tisserand Invariant     755
# ...

# %%
df[df['Hazardous'] ==False].count()
# Out:
# Neo Reference ID                3932
# Name                            3932
# Absolute Magnitude              3932
# Est Dia in KM(min)              3932
# Est Dia in KM(max)              3932
# Est Dia in M(min)               3932
# Est Dia in M(max)               3932
# Est Dia in Miles(min)           3932
# Est Dia in Miles(max)           3932
# Est Dia in Feet(min)            3932
# Est Dia in Feet(max)            3932
# Close Approach Date             3932
# Epoch Date Close Approach       3932
# Relative Velocity km per sec    3932
# Relative Velocity km per hr     3932
# Miles per hour                  3932
# Miss Dist.(Astronomical)        3932
# Miss Dist.(lunar)               3932
# Miss Dist.(kilometers)          3932
# Miss Dist.(miles)               3932
# Orbiting Body                   3932
# Orbit ID                        3932
# Orbit Determination Date        3932
# Orbit Uncertainity              3932
# Minimum Orbit Intersection      3932
# ...

# %%
df = df.drop(['Est Dia in M(min)', 'Est Dia in Miles(min)', 'Est Dia in Feet(min)',
                       'Est Dia in M(max)', 'Est Dia in Miles(max)', 'Est Dia in Feet(max)',
                       'Relative Velocity km per hr',
                       'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)','Miss Dist.(miles)'], axis=1)

# %%
df[df["Equinox"]!="J2000"]
# Out:
# Empty DataFrame
# Columns: [Neo Reference ID, Name, Absolute Magnitude, Est Dia in KM(min), Est Dia in KM(max), Close Approach Date, Epoch Date Close Approach, Relative Velocity km per sec, Miles per hour, Miss Dist.(kilometers), Orbiting Body, Orbit ID, Orbit Determination Date, Orbit Uncertainity, Minimum Orbit Intersection, Jupiter Tisserand Invariant, Epoch Osculation, Eccentricity, Semi Major Axis, Inclination, Asc Node Longitude, Orbital Period, Perihelion Distance, Perihelion Arg, Aphelion Dist, Perihelion Time, Mean Anomaly, Mean Motion, Equinox, Hazardous]
# Index: []
#
# [0 rows x 30 columns]

# %%
#dropping empty attribute
df = df.drop('Equinox',axis=1)

# %%
df['Hazardous'] = df['Hazardous'].apply(lambda x: 1 if x == True else 0)

# %%
df['Orbiting Body']
# Out:
# 0       Earth
# 1       Earth
# 2       Earth
# 3       Earth
# 4       Earth
#         ...
# 4682    Earth
# 4683    Earth
# 4684    Earth
# 4685    Earth
# 4686    Earth
# Name: Orbiting Body, Length: 4687, dtype: object

# %%
#showing that all ateroids were orbiting Earth
df[df['Orbiting Body']!='Earth']
# Out:
# Empty DataFrame
# Columns: [Neo Reference ID, Name, Absolute Magnitude, Est Dia in KM(min), Est Dia in KM(max), Close Approach Date, Epoch Date Close Approach, Relative Velocity km per sec, Miles per hour, Miss Dist.(kilometers), Orbiting Body, Orbit ID, Orbit Determination Date, Orbit Uncertainity, Minimum Orbit Intersection, Jupiter Tisserand Invariant, Epoch Osculation, Eccentricity, Semi Major Axis, Inclination, Asc Node Longitude, Orbital Period, Perihelion Distance, Perihelion Arg, Aphelion Dist, Perihelion Time, Mean Anomaly, Mean Motion, Hazardous]
# Index: []
#
# [0 rows x 29 columns]

# %%
df = df.drop('Orbiting Body' , axis =1)

# %%
df['Orbit Determination Date']
# Out:
# 0       2017-04-06 08:36:37
# 1       2017-04-06 08:32:49
# 2       2017-04-06 09:20:19
# 3       2017-04-06 09:15:49
# 4       2017-04-06 08:57:58
#                ...
# 4682    2017-04-06 08:24:07
# 4683    2017-04-06 08:23:58
# 4684    2017-04-06 08:23:43
# 4685    2017-04-06 08:23:42
# 4686    2017-04-29 06:18:33
# Name: Orbit Determination Date, Length: 4687, dtype: object

# %%
df = df.drop('Orbit Determination Date' , axis =1 )

# %%
#display hazardous asteroids with name, absolute magnitude and close approach date
df[df['Hazardous']==True][['Name', 'Absolute Magnitude', 'Close Approach Date']]
# Out:
#          Name  Absolute Magnitude Close Approach Date
# 0     3703080                21.6          1995-01-01
# 2     2446862                20.3          1995-01-08
# 4     3514799                21.6          1995-01-15
# 9     2306383                21.5          1995-01-22
# 22    3005973                21.7          1995-02-22
# ...       ...                 ...                 ...
# 4662  3744785                19.3          2016-08-08
# 4663  3755345                21.5          2016-08-08
# 4665  2333578                20.2          2016-08-15
# 4668  3475236                21.6          2016-08-15
# 4674  2068346                16.9          2016-09-08
#
# [755 rows x 3 columns]

# %%
#display asteroids with absolute magnitude more than '20' and having more than zero Orbit Uncertainity 
df[(df['Absolute Magnitude']>20) & (df['Orbit Uncertainity']>0)][['Name','Absolute Magnitude','Orbit Uncertainity']]
# Out:
#          Name  Absolute Magnitude  Orbit Uncertainity
# 0     3703080                21.6                   5
# 1     3723955                21.3                   3
# 3     3092506                27.4                   6
# 4     3514799                21.6                   1
# 10    3444370                22.4                   6
# ...       ...                 ...                 ...
# 4681  3662283                20.7                   1
# 4682  3759007                23.9                   8
# 4683  3759295                28.2                   6
# 4684  3759714                22.7                   6
# 4685  3759720                21.8                   5
#
# [2987 rows x 3 columns]

# %% [markdown]
# ### PLOTS

# %%
#Matplotlib histogram to visualize the asteroid absolute magnitude distribution. 
#This could help to visualize the distribution of asteroid brightness.
plt.figure(figsize=(8,5))
abs_mag = df['Absolute Magnitude']
plt.hist(abs_mag, bins=20, color='green')
plt.xlabel('Absolute Magnitude')
plt.ylabel('Count')
plt.title('Distribution of Asteroid Absolute Magnitudes')
plt.show()

# %%
#Seaborn scatter plot to visualize the relationship between asteroid size and miss distance. 
#This could help to understand whether larger asteroids tend to pass closer or further from Earth.
plt.figure(figsize=(8,8))
size = df['Est Dia in KM(max)']
miss_dist = df['Miss Dist.(kilometers)']
sns.scatterplot(x=size, y=miss_dist)
plt.xlabel('Maximum Estimated Asteroid Diameter (km)')
plt.ylabel('Miss Distance from Earth (km)')
plt.title('Relationship Between Asteroid Size and Miss Distance')
plt.show()

# %%
#create a correlation upper triangle matrix
mask = np.triu(np.ones_like(df, dtype = np.bool_))

# %%
correlation_mat = df.corr()

# %% [markdown]
#  we take absolute values of the dataframe since negative value correlation indicate strong relation but in inverse fashion.
#
# #positive values are have a linear relation.

# %%
#create heatmap(s) with the correlating matrix of information
mask = np.triu(np.ones_like(correlation_mat, dtype = np.bool_))
fig, ax = plt.subplots()
fig.set_size_inches(30, 20)
cmap = sns.color_palette("mako",as_cmap =True)
sns.heatmap(correlation_mat,linewidths = 0.5,cmap = cmap , annot = True , mask = mask)
# Out:
# <AxesSubplot:>

# %%
correlation_mat = df.corr().abs()

# %%
mask = np.triu(np.ones_like(correlation_mat, dtype = np.bool_))
fig, ax = plt.subplots()
fig.set_size_inches(30, 20)
cmap = sns.color_palette("mako",as_cmap =True)
sns.heatmap(correlation_mat,linewidths = 0.5,cmap = cmap , annot = True , mask = mask)
# Out:
# <AxesSubplot:>

# %%
df = df.drop(["Miles per hour",'Name'],axis = 1)

# %% [markdown]
# we can say the relation between name and Neo refrence ID should not be possible since they are just identifiers.
# simple solution to this is to just remove one of them
# in our case we will remove name.
#
# We also removed miles per hour because we are trying to use one

# %%
df.columns
# Out:
# Index(['Neo Reference ID', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity km per sec',
#        'Miss Dist.(kilometers)', 'Orbit ID', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Hazardous'],
#       dtype='object')

# %%
df = df.drop("Close Approach Date",axis = 1)

# %%
df["Perihelion Time"]
# Out:
# 0       2.458162e+06
# 1       2.457795e+06
# 2       2.458120e+06
# 3       2.457902e+06
# 4       2.457814e+06
#             ...
# 4682    2.457708e+06
# 4683    2.458088e+06
# 4684    2.458300e+06
# 4685    2.458288e+06
# 4686    2.458319e+06
# Name: Perihelion Time, Length: 4687, dtype: float64

# %%
df.columns
# Out:
# Index(['Neo Reference ID', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Epoch Date Close Approach',
#        'Relative Velocity km per sec', 'Miss Dist.(kilometers)', 'Orbit ID',
#        'Orbit Uncertainity', 'Minimum Orbit Intersection',
#        'Jupiter Tisserand Invariant', 'Epoch Osculation', 'Eccentricity',
#        'Semi Major Axis', 'Inclination', 'Asc Node Longitude',
#        'Orbital Period', 'Perihelion Distance', 'Perihelion Arg',
#        'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly', 'Mean Motion',
#        'Hazardous'],
#       dtype='object')

# %%
df = df.drop("Neo Reference ID",axis=1)

# %%
x = df.drop('Hazardous',axis = 1)
y = df['Hazardous']

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler( random_state=9)
x_resampled, y_resampled = ros.fit_resample(x, y) #over sampled minority

# %%
x_train,x_test,y_train,y_test = train_test_split(x_resampled,y_resampled,test_size=0.3,random_state= 9)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit_transform(x_train)
scaler.transform(x_test)
# Out:
# array([[-1.16415199,  1.07644148,  1.07644148, ...,  0.48583768,
#          1.19896815, -1.49188436],
#        [-0.40231069, -0.07385101, -0.07385101, ...,  0.5100277 ,
#          0.61973628, -0.77425402],
#        [ 1.95939734, -0.79090226, -0.79090226, ...,  0.54743928,
#         -0.03808244, -0.18543568],
#        ...,
#        [ 0.85472746, -0.66823157, -0.66823157, ..., -2.35686973,
#          1.02316734,  0.4801337 ],
#        [-0.21185036, -0.23033279, -0.23033279, ...,  0.0460901 ,
#         -0.80610376, -0.67148233],
#        [ 0.85472746, -0.66823157, -0.66823157, ...,  0.76289017,
#          0.53728779, -1.41581397]])

# %% [markdown]
# Creating a gridsearch model for SVC

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.svm import SVC
svm = SVC()
param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],'kernel': ['rbf']} 
grid = GridSearchCV(svm,param_grid)
grid.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14768\2291447545.py in <module>
#       4 param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],'kernel': ['rbf']}
#       5 grid = GridSearchCV(svm,param_grid)
# ----> 6 grid.fit(x_train,y_train)
#
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# ...

# %%
grid.best_estimator_
grid.best_params_

# %%
y_pred = grid.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      1.00      0.99      1165\n           1       1.00      0.99      0.99      1195\n\n    accuracy                           0.99      2360\n   macro avg       0.99      0.99      0.99      2360\nweighted avg       0.99      0.99      0.99      2360\n'

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test,y_pred)
# Out:
# array([[1165,    0],
#        [  14, 1181]])

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier()

dt_model = dt_model.fit(x_train,y_train)

# %%
y_test
# Out:
# 6632    1
# 5694    1
# 2460    0
# 203     0
# 589     0
#        ..
# 1986    0
# 5176    1
# 2962    0
# 6719    1
# 4140    0
# Name: Hazardous, Length: 2360, dtype: int64

# %%
y_pred_dt = dt_model.predict(x_test)

classification_report(y_test,y_pred_dt)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      1165\n           1       1.00      1.00      1.00      1195\n\n    accuracy                           1.00      2360\n   macro avg       1.00      1.00      1.00      2360\nweighted avg       1.00      1.00      1.00      2360\n'

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()
logistic_model = logistic_model.fit(x_train,y_train)

y_pred_logistic = logistic_model.predict(x_test)

classification_report(y_test,y_pred_logistic)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Out:
# /home/labib/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/labib/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/labib/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/labib/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/labib/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
#Using Neural network for the model

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout

model_Ann = Sequential()

# %%
#Input Layer
model_Ann.add(Dense(units = 64,activation='relu'))
#Hidden Layers
model_Ann.add(Dense(units = 32,activation='relu'))
#Output Layer:\
model_Ann.add(Dense(units = 1,activation='sigmoid'))

# %%
model_Ann.compile(loss='binary_crossentropy',optimizer='Adam')

# %%
model_Ann.fit(x_train,y_train,epochs=600)
# Out:
# Epoch 1/600
# 172/172 [==============================] - 1s 726us/step - loss: 2903049984.0000
# Epoch 2/600
# 172/172 [==============================] - 0s 749us/step - loss: 2057388416.0000
# Epoch 3/600
# 172/172 [==============================] - 0s 709us/step - loss: 1808854784.0000
# Epoch 4/600
# 172/172 [==============================] - 0s 709us/step - loss: 1399511040.0000
# Epoch 5/600
# 172/172 [==============================] - 0s 729us/step - loss: 1617476096.0000
# Epoch 6/600
# 172/172 [==============================] - 0s 752us/step - loss: 1882429824.0000
# Epoch 7/600
# 172/172 [==============================] - 0s 706us/step - loss: 1549414144.0000
# Epoch 8/600
# 172/172 [==============================] - 0s 682us/step - loss: 1619041536.0000
# Epoch 9/600
# 172/172 [==============================] - 0s 700us/step - loss: 1472534528.0000
# Epoch 10/600
# 172/172 [==============================] - 0s 744us/step - loss: 1485902976.0000
# Epoch 11/600
# ...

# %%
err= model_Ann.history.history['loss']

# %%
sns.lineplot(x=np.arange(600),y=err)
# Out:
# <AxesSubplot:>

# %%
predict_ann = model_Ann.predict(x_test)
print("accuracy = ",predict_ann * 100)
# Out:
# 74/74 [==============================] - 0s 560us/step
# accuracy =  [[50.04431]
#  [50.04431]
#  [50.04431]
#  ...
#  [50.04431]
#  [50.04431]
#  [50.04431]]

# %%
result = model_Ann.evaluate(x_test,y_test)

print("loss score ",result*100)
# Out:
# 74/74 [==============================] - 0s 724us/step - loss: 0.6925
# loss score  69.25479769706726

# %%
#Create Another Nueral network with more layers
model_Ann2 = Sequential()

# %%
#Input Layer
model_Ann2.add(Dense(units = 64,activation='relu'))
#Hidden Layer1
model_Ann2.add(Dense(units = 32,activation='relu'))
#Hidden Layer 2
model_Ann2.add(Dense(units = 16,activation='relu'))
#Hidden Layer 3
model_Ann2.add(Dense(units = 8,activation='relu'))
#Hiddem Layer 4
model_Ann2.add(Dense(units = 4,activation='relu'))
#Output Layer:\
model_Ann2.add(Dense(units = 1,activation='sigmoid'))

# %%
model_Ann2.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
model_Ann2.fit(x_train,y_train,epochs=201)
# Out:
# Epoch 1/301
# 172/172 [==============================] - 1s 799us/step - loss: 2619797504.0000 - accuracy: 0.5038
# Epoch 2/301
# 172/172 [==============================] - 0s 974us/step - loss: 1818214784.0000 - accuracy: 0.5013
# Epoch 3/301
# 172/172 [==============================] - 0s 828us/step - loss: 1266963840.0000 - accuracy: 0.4893
# Epoch 4/301
# 172/172 [==============================] - 0s 986us/step - loss: 1009341184.0000 - accuracy: 0.4969
# Epoch 5/301
# 172/172 [==============================] - 0s 1ms/step - loss: 383816736.0000 - accuracy: 0.4896
# Epoch 6/301
# 172/172 [==============================] - 0s 907us/step - loss: 216665440.0000 - accuracy: 0.4922
# Epoch 7/301
# 172/172 [==============================] - 0s 817us/step - loss: 172893072.0000 - accuracy: 0.4995
# Epoch 8/301
# 172/172 [==============================] - 0s 863us/step - loss: 77103416.0000 - accuracy: 0.4944
# Epoch 9/301
# ...

# %%
accuracy_2 = model_Ann2.evaluate(x_test,y_test)
# Out:
# 74/74 [==============================] - 0s 704us/step - loss: 0.6932 - accuracy: 0.4936

# %%
#This time we do not oversample and fit it with untouched data (x,y)

#i will only scale the data
x1_train,x1_test,y1_train,y1_test = train_test_split(x,y,test_size=0.3,random_state= 6)

# %%
# scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x1_train)
scaler.transform(x1_train)
scaler.transform(x1_test)
# Out:
# array([[-0.40015446, -0.14308444, -0.14308444, ...,  0.31199554,
#          1.53834383, -0.52586613],
#        [ 0.39708892, -0.4991936 , -0.4991936 , ...,  0.40643718,
#          0.38475605,  1.49766764],
#        [-0.50414272, -0.0623224 , -0.0623224 , ...,  0.30157378,
#          1.55087236,  0.78250092],
#        ...,
#        [-0.19217792, -0.2746895 , -0.2746895 , ...,  0.16795784,
#         -0.19565238,  1.89356856],
#        [-0.26150343, -0.23479398, -0.23479398, ...,  0.46062221,
#          0.51065277,  0.07060194],
#        [-2.20261773,  5.28895343,  5.28895343, ...,  0.32012885,
#          1.49895299, -0.53100176]])

# %%
model = Sequential()
model.add(Dense(20, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x1_train,y1_train,epochs = 201)
# Out:
# Epoch 1/201
# 103/103 [==============================] - 1s 821us/step - loss: 1766892160.0000 - accuracy: 0.7223
# Epoch 2/201
# 103/103 [==============================] - 0s 851us/step - loss: 790593408.0000 - accuracy: 0.7448
# Epoch 3/201
# 103/103 [==============================] - 0s 841us/step - loss: 1828521472.0000 - accuracy: 0.7357
# Epoch 4/201
# 103/103 [==============================] - 0s 909us/step - loss: 2061934720.0000 - accuracy: 0.7320
# Epoch 5/201
# 103/103 [==============================] - 0s 1ms/step - loss: 1094354048.0000 - accuracy: 0.7265
# Epoch 6/201
# 103/103 [==============================] - 0s 963us/step - loss: 1365057792.0000 - accuracy: 0.7302
# Epoch 7/201
# 103/103 [==============================] - 0s 973us/step - loss: 955563776.0000 - accuracy: 0.7326
# Epoch 8/201
# 103/103 [==============================] - 0s 841us/step - loss: 928744320.0000 - accuracy: 0.7271
# Epoch 9/201
# ...

# %%
err= model.history.history['loss']

# %%
sns.lineplot(x=np.arange(201),y=err)
# Out:
# <AxesSubplot:>

# %%
model.evaluate(x1_train,y1_train)
# Out:
# 103/103 [==============================] - 0s 665us/step - loss: 0.4458 - accuracy: 0.8363
# [0.44578757882118225, 0.8362804651260376]

# %%
pred = model.evaluate(x1_test,y1_test)

print('test results ==',pred[1]*100)
# Out:
# 44/44 [==============================] - 0s 673us/step - loss: 0.4314 - accuracy: 0.8451
# test results == 84.5060408115387

# %%
#Now using feature MinMax Feature scaling method without oversalmpling

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x,y,test_size=0.3,random_state= 6)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x1_train = scaler.fit_transform(x1_train)
x1_test = scaler.transform(x1_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout

model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='Adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x1_train,y1_train,epochs = 201)
# Out:
# Epoch 1/201
# 103/103 [==============================] - 1s 939us/step - loss: 0.3875 - accuracy: 0.8375
# Epoch 2/201
# 103/103 [==============================] - 0s 870us/step - loss: 0.2719 - accuracy: 0.8811
# Epoch 3/201
# 103/103 [==============================] - 0s 831us/step - loss: 0.2118 - accuracy: 0.9134
# Epoch 4/201
# 103/103 [==============================] - 0s 851us/step - loss: 0.1648 - accuracy: 0.9351
# Epoch 5/201
# 103/103 [==============================] - 0s 958us/step - loss: 0.1434 - accuracy: 0.9384
# Epoch 6/201
# 103/103 [==============================] - 0s 1ms/step - loss: 0.1245 - accuracy: 0.9494
# Epoch 7/201
# 103/103 [==============================] - 0s 978us/step - loss: 0.1204 - accuracy: 0.9500
# Epoch 8/201
# 103/103 [==============================] - 0s 851us/step - loss: 0.1061 - accuracy: 0.9567
# Epoch 9/201
# 103/103 [==============================] - 0s 860us/step - loss: 0.1099 - accuracy: 0.9527
# Epoch 10/201
# ...

# %%
mod_hist = model.history.history['loss']
plt.plot(mod_hist)

# %%
pred = model.evaluate(x1_test,y1_test)
# Out:
# 44/44 [==============================] - 0s 719us/step - loss: 0.0547 - accuracy: 0.9844

# %%
print('model accuracy = ',pred[1]*100)
# Out:
# model accuracy =  98.43639135360718
